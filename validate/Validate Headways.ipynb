# %% [markdown]
# # notebook to validate headway calculations
# ## comparing selected stops to agency timetables

# %%
import pandas as pd, numpy as np, os

# %%
# field data types for a more efficient load

df_types = {
    'Agency': np.dtype('O'),
    'IB AM Peak': np.dtype('float64'),
    'IB PM Peak': np.dtype('float64'),
    'IB Routes': np.dtype('O'),
    'IB Saturday': np.dtype('float64'),
    'IB Sunday': np.dtype('float64'),
    'IB Weekday': np.dtype('float64'),
    'Name': np.dtype('O'),
    'OB AM Peak': np.dtype('float64'),
    'OB PM Peak': np.dtype('float64'),
    'OB Routes': np.dtype('O'),
    'OB Saturday': np.dtype('float64'),
    'OB Sunday': np.dtype('float64'),
    'OB Weekday': np.dtype('float64'),
    'Stop ID': np.dtype('O'),
    'Unnamed: 0': np.dtype('int64'),
    'X': np.dtype('float64'),
    'Y': np.dtype('float64')
}

# %%
df = pd.read_csv('output/AllBus.csv', dtype=df_types)

# %%
list_of_agencies = list(os.walk('gtfs'))[0][1]

path = "gtfs/" + list_of_agencies[np.random.randint(0, len(list_of_agencies))] + "/"
path
# Out:
# 'gtfs/golden-empire-transit-district--340/'

# %%
print(path)
print("-------")

agency_name = pd.read_csv(path + 'agency.txt')['agency_name'][0]
agency_name = agency_name.replace("/","-")
print(agency_name)

trips = pd.read_csv(path + 'trips.txt')
print(len(trips), "trips")

routes = pd.read_csv(path + 'routes.txt')
print(len(routes), "routes")

stops = pd.read_csv(path + 'stops.txt')
print(len(stops), "stops")

stop_times = pd.read_csv(path + 'stop_times.txt')
print(len(stop_times), "stop times")

calendar = pd.read_csv(path + "calendar.txt")
print(len(calendar), "schedules")

calendar_dates = pd.read_csv(path + "calendar_dates.txt")
print(len(calendar_dates), "exception dates")
# Out:
# gtfs/marin-transit--345/
# -------
# Marin Transit
# 2174 trips
# 27 routes
# 587 stops
# 52012 stop times
# 32 schedules
# 47 exception dates

# %%
trips2routes = dict(zip(trips['trip_id'], trips['route_id']))
routes2headsigns = dict(zip(routes['route_id'], routes['route_short_name']))

# %%
stop_times.head()
# Out:
#    trip_id arrival_time departure_time stop_id  stop_sequence  stop_headsign  \
# 0   778652     18:47:00       18:47:00     290              1            NaN
# 1   778652     18:48:00       18:48:00    1600              2            NaN
# 2   778652     18:48:00       18:48:00    1602              3            NaN
# 3   778652     18:49:00       18:49:00    1603              4            NaN
# 4   778652     18:50:00       18:50:00    1604              5            NaN
#
#    pickup_type  drop_off_type  shape_dist_traveled
# 0          NaN            NaN                  NaN
# 1          NaN            NaN                  NaN
# 2          NaN            NaN                  NaN
# 3          NaN            NaN                  NaN
# 4          NaN            NaN                  NaN

# %%
tempDF = stop_times.query("stop_sequence ==1")[['trip_id', 'stop_id']]
tempDF['route_short_name'] = [routes2headsigns[trips2routes[x]] for x in list(tempDF['trip_id'])]
tempDF['route_id'] = [trips2routes[x] for x in list(tempDF['trip_id'])]

# %%
tempDF.drop_duplicates(subset=['stop_id', 'route_short_name'],inplace=True)

tempDF['agency'] = agency_name

tempDF
# Out:
#                    trip_id  stop_id route_short_name  route_id  \
# 0     t_209005_b_6600_tn_0   782812                C      1965
# 232   t_209119_b_6600_tn_0   782847                C      1965
# 418   t_209128_b_6600_tn_0   782799                C      1965
# 437   t_209129_b_6600_tn_0   782752                C      1965
# 459   t_209311_b_6600_tn_0   782805                C      1965
# 548   t_255298_b_7159_tn_0   782723               60      1961
# 571   t_255299_b_7159_tn_0   782761               60      1961
# 1063  t_255324_b_7159_tn_0   782847              50x      1968
# 1080  t_255325_b_7159_tn_0   782761              50x      1968
# 1258  t_255336_b_7159_tn_1   782761               30      1963
# 1298  t_255337_b_7159_tn_0   782761               20      1962
# 1627  t_255350_b_7159_tn_0   782726               20      1962
# 1886  t_255359_b_7159_tn_1   782781               40      1964
# 2526  t_255368_b_7160_tn_1   782761               35      4708
# 2678  t_255369_b_7160_tn_0   782761               25      1970
# 2782  t_281576_b_7160_tn_0   782723               25      1970
# 2882  t_281586_b_7159_tn_1   782799               70      6433
#
#                  agency
# 0     El Dorado Transit
# 232   El Dorado Transit
# 418   El Dorado Transit
# 437   El Dorado Transit
# 459   El Dorado Transit
# 548   El Dorado Transit
# 571   El Dorado Transit
# 1063  El Dorado Transit
# 1080  El Dorado Transit
# 1258  El Dorado Transit
# 1298  El Dorado Transit
# 1627  El Dorado Transit
# 1886  El Dorado Transit
# 2526  El Dorado Transit
# 2678  El Dorado Transit
# 2782  El Dorado Transit
# 2882  El Dorado Transit

# %%
concatList = []

for agency in list_of_agencies:
    path = "gtfs/" + agency + "/" 
    #print(path)
    
    print("-------")

    agency_name = pd.read_csv(path + 'agency.txt')['agency_name'][0]
    agency_name = agency_name.replace("/","-")
    print(agency_name)

    # load in GTFS data
    trips = pd.read_csv(path + 'trips.txt')
    routes = pd.read_csv(path + 'routes.txt')
    stop_times = pd.read_csv(path + 'stop_times.txt')
    
    # store trip/route information in dictionary
    trips2routes = dict(zip(trips['trip_id'], trips['route_id']))
    routes2headsigns = dict(zip(routes['route_id'], routes['route_short_name']))
    routes2route_type = dict(zip(routes['route_id'], routes['route_type']))
    
    tempDF = stop_times.query("stop_sequence ==1")[['trip_id', 'stop_id']]
    if len(tempDF) != 0:
        try:
            tempDF['route_short_name'] = [routes2headsigns[trips2routes[x]] for x in list(tempDF['trip_id'])]
            tempDF['route_id'] = [trips2routes[x] for x in list(tempDF['trip_id'])]
            tempDF['route_type'] = [routes2route_type[x] for x in list(tempDF['route_id'])]
        except KeyError:
            tempDF['route_short_name'] = [routes2headsigns[trips2routes[str(x)]] for x in list(tempDF['trip_id'])]
            tempDF['route_id'] = [trips2routes[str(x)] for x in list(tempDF['trip_id'])]
            tempDF['route_type'] = [routes2route_type[str(x)] for x in list(tempDF['route_id'])]
        
        tempDF.query("route_type == 3", inplace=True)
        
        tempDF.drop_duplicates(subset=['stop_id', 'route_short_name'],inplace=True)
        tempDF['agency'] = agency_name
        tempDF.drop(['trip_id', 'route_type'], axis=1, inplace=True)
        
        concatList.append(tempDF)
    else:
        pass

origins = pd.concat(concatList, ignore_index=True)
origins.head()
# Out:
# -------
# Caltrain
# -------
# Marin Transit
# -------
# Bay Area Rapid Transit
# -------
# Spirit Bus
# -------
# El Dorado Transit
# -------
# Blue & Gold Fleet
# -------
# Big Blue Bus
# /Users/mapsense-simon/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# -------
# North County Transit District
# -------
# Sacramento Regional Transit
# /Users/mapsense-simon/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# -------
# Redding Area Bus Authority
# -------
# Trinity Transit
# -------
# Riverside Transit Agency
# -------
# Sunline Transit Agency
# -------
# Metro - Los Angeles
# /Users/mapsense-simon/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# -------
# eTrans
# -------
# Corona Cruiser
# -------
# Norwalk Transit System
# -------
# LADOT
# -------
# Anaheim Resort Transportation
# -------
# MTS
# /Users/mapsense-simon/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (8,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# -------
# Eureka Transit Service
# -------
# Lake Transit
# -------
# Madera County Connection
# -------
# Lassen Rural Bus
# -------
# Yuba-Sutter Transit
# -------
# Laguna Beach Transit
# -------
# Metrolink Trains
# -------
# Mendocino Transit Authority
# -------
# Altamont Corridor Express
# -------
# Glendale Beeline
# -------
# Yosemite Valley Shuttle System
# -------
# Airport Valet Express
# -------
# Gold Coast Transit
# -------
# Livermore Amador Valley Transit Authority
# -------
# Palo Verde Valley Transit Agency
# -------
# SamTrans
# -------
# San Francisco Bay Ferry
# -------
# San Joaquin Regional Transit District (RTD)
# -------
# Petaluma Transit
# -------
# Emery Go-Round
# -------
# Metro - Los Angeles
# -------
# Golden Empire Transit District
# -------
# Orange County Transportation Authority
# -------
# MVgo Mountain View
# -------
# Santa Cruz Metro
# -------
# Redwood Coast Transit
# -------
# Modesto Area Express
# -------
# Turlock Transit
# -------
# Fresno Public Transportation (FAX)
# -------
# San Francisco Municipal Transportation Agency
# -------
# County Connection
# -------
# Siskiyou Transit and General Express
# -------
# Palos Verdes Peninsula Transit Authority
# -------
# WestCat (Western Contra Costa)
# -------
# Yolo County Transportation District
# -------
# Amador Transit
# -------
# AC Transit
# -------
# OMNITRANS
# -------
# Duarte Transit
# -------
# City of San Luis Obispo Transit
# -------
# Thousand Oaks Transit
# -------
# San Francisco Municipal Transportation Agency
# -------
# Nevada County Gold Country Stage
# -------
# VTA
# -------
# TORRANCE TRANSIT SYSTEM
# -------
# The Bus
# -------
# Foothill Transit
# -------
# Mountain Transit
# -------
# Beaumont Pass Transit
# -------
# Tahoe Truckee Area Regional Transit
# -------
# Monterey-Salinas Transit
# -------
# Unitrans (Davis)
# -------
# Capitol Corridor Joint Powers Authority
# -------
# Sage Stage
# -------
# San Benito County Express
# -------
# Tideline Water Taxi
# -------
# Kern Transit
# -------
# El Monte Transit
# -------
# City of Lodi Transit-GrapeLine
# -------
# Fairfield and Suisun Transit
# -------
# Eastern Sierra Transit Authority
# -------
# Glendale Beeline
# -------
# Ventura County Transportation Commission
# -------
# Stanford Marguerite Shuttle
# -------
# Guadalupe Flyer
# -------
# Sonoma County Transit
# -------
# Long Beach Transit
# -------
# Avalon Transit
# -------
# Susanville Indian Rancheria Public Transportation Program
# -------
# Golden Gate Transit
# -------
# San Luis Obispo Regional Transit Authority
# -------
# Calaveras Transit
# -------
# Mendocino Transit Authority
# -------
# SolTrans
# -------
# Victor Valley Transit Authority
# -------
# Rio Vista Delta Breeze
# -------
# Plumas Transit
# -------
# Simi Valley Transit
# -------
# Fresno County Rural Transit Agency
#    stop_id route_short_name  route_id         agency
# 0   777402     TaSJ-Shuttle  TaSj-130       Caltrain
# 1   777403     TaSJ-Shuttle  TaSj-130       Caltrain
# 2  2452018               17     10897  Marin Transit
# 3  2451865               17     10897  Marin Transit
# 4  2452018               22     10898  Marin Transit

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Stop ID', 'Name', 'Agency', 'X', 'Y', 'OB Routes',
#        'OB AM Peak', 'OB PM Peak', 'OB Weekday', 'OB Saturday', 'OB Sunday',
#        'IB Routes', 'IB AM Peak', 'IB PM Peak', 'IB Weekday', 'IB Saturday',
#        'IB Sunday'],
#       dtype='object')

# %%
origins.shape
# Out:
# (4948, 4)

# %%
merged = origins.merge(df, how='inner', left_on=["stop_id","agency"], right_on=["Stop ID", "Agency"])

# %%
list(merged.columns)
# Out:
# ['stop_id',
#  'route_short_name',
#  'route_id',
#  'agency',
#  'Unnamed: 0',
#  'Stop ID',
#  'Name',
#  'Agency',
#  'X',
#  'Y',
#  'OB Routes',
#  'OB AM Peak',
#  'OB PM Peak',
#  'OB Weekday',
#  'OB Saturday',
#  'OB Sunday',
#  'IB Routes',
#  'IB AM Peak',
#  'IB PM Peak',
#  'IB Weekday',
#  'IB Saturday',
#  'IB Sunday']

# %% [markdown]
# merged.head()

# %%
keeperCols = ['stop_id',
 'route_short_name',
 'route_id',
 'Stop ID',
 'Name',
 'Agency',
 'OB Routes',
 'OB AM Peak',
 'OB PM Peak',
 'OB Weekday',
 'OB Saturday',
 'OB Sunday',
 'IB Routes',
 'IB AM Peak',
 'IB PM Peak',
 'IB Weekday',
 'IB Saturday',
 'IB Sunday']
merged[keeperCols].to_csv("ValidateTest.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Stop ID                            Name         Agency  \
# 0           0   777402       San Jose Caltrain Station       Caltrain
# 1           1   777403         Tamien Caltrain Station       Caltrain
# 2           0  2452018       San Rafael Transit Center  Marin Transit
# 3           1  2452379      Hwy 101 @ Lucky Dr Bus Pad  Marin Transit
# 4           2  2452231  Hwy 101 @ Tamalpais Dr Bus Pad  Marin Transit
#
#             X          Y                                          OB Routes  \
# 0 -121.901985  37.330196                                       TaSJ-Shuttle
# 1 -121.883403  37.311638                                       TaSJ-Shuttle
# 2 -122.523102  37.971081  125, 245, 29, 22, 49, 228, 35, 68, 233, 36, 25...
# 3 -122.517030  37.937937                                                NaN
# 4 -122.515205  37.926495                                                119
#
#    OB AM Peak  OB PM Peak  OB Weekday  OB Saturday  OB Sunday  \
# 0         NaN         NaN         NaN        93.33      93.33
# 1         NaN         NaN         NaN        93.33      93.33
# 2         8.0         7.5         8.5        10.91      10.91
# 3         NaN         NaN         NaN          NaN        NaN
# 4         NaN       240.0       480.0          NaN        NaN
#
#                                            IB Routes  IB AM Peak  IB PM Peak  \
# 0                                       TaSJ-Shuttle         NaN         NaN
# 1                                       TaSJ-Shuttle         NaN         NaN
# 2  125, 245, 29, 22, 49, 228, 35, 68, 233, 36, 25...        7.74        8.89
# 3                                             36, 17       18.46       17.14
# 4                                             36, 17       18.46       17.14
#
#    IB Weekday  IB Saturday  IB Sunday
# 0         NaN        70.00      70.00
# 1         NaN        70.00      70.00
# 2        8.97         9.44       9.55
# 3       20.43        25.45      25.45
# 4       20.43        25.45      25.45

# %%
len(df)
# Out:
# 98913

# %%
(len(df) - len(df.drop_duplicates()))/len(df)
# Out:
# 0.1798954636903137

# %%
df['Stop ID'].value_counts()
# Out:
# 111                                     20
# 127                                     18
# 108                                     18
# 112                                     17
# 232                                     17
# 128                                     17
# 360                                     17
# 132                                     17
# 356                                     17
# 103                                     17
# 119                                     17
# 213                                     16
# 353                                     16
# 331                                     16
# 229                                     16
# 187                                     16
# 125                                     16
# 205                                     16
# 143                                     16
# 231                                     16
# 334                                     16
# 307                                     16
# 110                                     16
# 126                                     16
# 226                                     16
# 120                                     16
# 137                                     16
# 403                                     16
# 352                                     16
# 246                                     16
#                                         ..
# 335525                                   1
# 1013840                                  1
# 27730                                    1
# 813057                                   1
# 341270                                   1
# 99442                                    1
# 760867                                   1
# 9572c396-195a-490f-86d7-15014321138e     1
# 99448                                    1
# S2000                                    1
# 300920                                   1
# 1502830                                  1
# 704530                                   1
# 104600                                   1
# 805035                                   1
# 832181                                   1
# 1001220                                  1
# 28761                                    1
# 21891                                    1
# 20713                                    1
# 22345                                    1
# 1015290                                  1
# 28654                                    1
# 9901750                                  1
# 831025                                   1
# 813047                                   1
# 813059                                   1
# 831947                                   1
# 783978                                   1
# 344900                                   1
# Name: Stop ID, Length: 41018, dtype: int64

# %%
df[df['Stop ID'] == "111"].sort_values("Agency")
# Out:
#        Unnamed: 0 Stop ID                                             Name  \
# 1695          818     111                             GRAND SB & VENICE NS
# 77852           5     111                               Johnson at La Cita
# 63407         733     111                                     MLK - JENSEN
# 91954          21     111                                 Brand & Monterey
# 35272          21     111                                 Brand & Monterey
# 54544         321     111                            Virginia & Washington
# 94147         280     111                              BATTAAN & CARSON SE
# 19463        6784     111                                  Arleta / Pierce
# 47045        6784     111                                  Arleta / Pierce
# 76765        1557     111                   Mt Vernon @ Centrepointe Sb Ns
# 55531         280     111                                    BEACH-LINCOLN
# 10307         810     111                                      14th + Lime
# 7759         4135     111                              Q ST & 11TH ST (EB)
# 5568         1944     111                              Q ST & 11TH ST (EB)
# 90809           0     111     Corner Of Main And West Fifth Ave (Rite Aid)
# 96717         202     111  East Branch Street @ Arroyo Grande City Hall WB
# 92549         176     111                               Stock Farm N @ Oak
# 12567         515     111                         Dr Carreon at Monroe JFK
# 85842         472     111                        CRENSHAW BL + MONTEREY ST
# 81723          92     111              OHLONE-CHYNOWETH LIGHT RAIL STATION
#
#                                            Agency           X          Y  \
# 1695                                 Big Blue Bus -118.266338  34.035810
# 77852             City of San Luis Obispo Transit -120.642441  35.269775
# 63407          Fresno Public Transportation (FAX) -119.799956  36.706467
# 91954                            Glendale Beeline -118.255230  34.157197
# 35272                            Glendale Beeline -118.255230  34.157197
# 54544              Golden Empire Transit District -118.975832  35.361210
# 94147                          Long Beach Transit -118.223366  33.831577
# 19463                         Metro - Los Angeles -118.435393  34.250737
# 47045                         Metro - Los Angeles -118.435393  34.250737
# 76765                                   OMNITRANS -117.309261  34.050133
# 55531      Orange County Transportation Authority -117.993720  33.831540
# 10307                    Riverside Transit Agency -117.374146  33.974327
# 7759                  Sacramento Regional Transit -121.495422  38.572105
# 5568                  Sacramento Regional Transit -121.495422  38.572105
# 90809                                  Sage Stage -120.542266  41.488518
# 96717  San Luis Obispo Regional Transit Authority -120.577143  35.124278
# 92549                 Stanford Marguerite Shuttle -122.183897  37.430661
# 12567                      Sunline Transit Agency -116.235454  33.707347
# 85842                     TORRANCE TRANSIT SYSTEM -118.328493  33.829327
# 81723                                         VTA -121.860927  37.257781
#
#                      OB Routes  OB AM Peak  OB PM Peak  OB Weekday  \
# 1695                       NaN         NaN         NaN         NaN
# 77852                       1A         NaN         NaN         NaN
# 63407                       32       30.00       30.00       33.10
# 91954                      NaN         NaN         NaN         NaN
# 35272                      NaN         NaN         NaN         NaN
# 54544                       46       34.29       30.00       33.10
# 94147                      NaN         NaN         NaN         NaN
# 19463                      158       48.00       40.00       53.33
# 47045                      158       48.00       40.00       53.33
# 76765                       19       30.00       34.29       32.00
# 55531                  29, 29A       16.00       17.14       18.46
# 10307                       13       60.00       80.00       68.57
# 7759                       NaN         NaN         NaN         NaN
# 5568                       NaN         NaN         NaN         NaN
# 90809  nan, nan, nan, nan, nan         NaN         NaN         NaN
# 96717                       24       60.00       60.00       73.85
# 92549                     SLAC       40.00       30.00       35.56
# 12567                       81       60.00       60.00       64.00
# 85842                      NaN         NaN         NaN         NaN
# 81723                       13       80.00       60.00       80.00
#
#        OB Saturday  OB Sunday                IB Routes  IB AM Peak  \
# 1695           NaN        NaN                      R10       48.00
# 77852        70.00      70.00                       1B         NaN
# 63407        36.52      36.52                      NaN         NaN
# 91954          NaN        NaN                        1      240.00
# 35272          NaN        NaN                        1      240.00
# 54544        38.18      38.18                      NaN         NaN
# 94147          NaN        NaN                      191       21.82
# 19463        70.00      60.00                      NaN         NaN
# 47045        70.00      60.00                      NaN         NaN
# 76765        64.62      76.36                      215       24.00
# 55531        21.54      22.11                      NaN         NaN
# 10307        84.00      84.00                   10, 54       30.00
# 7759           NaN        NaN               38, 109, 6       60.00
# 5568           NaN        NaN               6, 38, 109       80.00
# 90809          NaN        NaN  nan, nan, nan, nan, nan         NaN
# 96717        76.36      84.00                      NaN         NaN
# 92549          NaN        NaN                      NaN         NaN
# 12567        64.62      64.62                      NaN         NaN
# 85842          NaN        NaN                       10       30.00
# 81723          NaN        NaN                       13       60.00
#
#        IB PM Peak  IB Weekday  IB Saturday  IB Sunday
# 1695        21.82       34.29          NaN        NaN
# 77852         NaN         NaN          NaN        NaN
# 63407         NaN         NaN          NaN        NaN
# 91954      240.00      960.00       840.00     840.00
# 35272      240.00      960.00       840.00     840.00
# 54544         NaN         NaN          NaN        NaN
# 94147       26.67       29.09        42.00      42.00
# 19463         NaN         NaN          NaN        NaN
# 47045         NaN         NaN          NaN        NaN
# 76765       21.82       26.67        38.18      44.21
# 55531         NaN         NaN          NaN        NaN
# 10307       30.00       36.92       105.00     105.00
# 7759        80.00       87.27        93.33     120.00
# 5568        34.29       50.53       210.00     280.00
# 90809         NaN         NaN          NaN        NaN
# 96717         NaN         NaN          NaN        NaN
# 92549         NaN         NaN          NaN        NaN
# 12567         NaN         NaN          NaN        NaN
# 85842       26.67       30.00        52.50        NaN
# 81723       80.00       73.85          NaN        NaN

# %%
df.drop_duplicates(subset=["Stop ID", "Agency"]).to_csv('output/AllBus_DeDuped.csv')
